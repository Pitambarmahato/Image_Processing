# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread('a.jpg')
#image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAYSCALE)
plt.imshow(image)

# %%
image.shape
# Out:
# (514, 800, 3)

# %% [markdown]
# # Image Resizing

# %%
#resize = cv2.resize(image, (100, 100))
resize = cv2.resize(image, None, fx = 0.5, fy = 0.5)
plt.imshow(resize)

# %% [markdown]
# # Image Thresholding

# %% [markdown]
# ### What was the parameters that should be pass during the thresholding of an image
# * At first we need to pass the source image as the first parameter
# * another parameter is the threshold value from which we are going to classify the image pixels
# * third argument is the highest pixel value which is given to the image when the pixel values are more than our threshold value
# * the fourth parameter determines the style of the thresholding which may be binary and adaptive thresholding

# %%
ret, thresh1 = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY_INV) #In this thresholding method we have done the inverse binary thresholding
plt.imshow(threshold, cmap = 'gray')

# %%
#Here we are doing binary thresholding 
_, threshold = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY) #you can change the values of the range. THRESH_BINARY vs OTSU vs Adaptive Thresholding
#print(threshold)
plt.imshow(threshold, cmap = 'gray')

# %% [markdown]
# Read about Different Thresholding Techniques:
# * Binary
# * Adaptive Thresholding

# %% [markdown]
# # Image Masking
