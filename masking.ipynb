# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
sky_bg = cv2.imread('sky.jpg')
image2 = cv2.imread('flower2.jpg')
plt.imshow(image2_gray)

# %%
lv = np.array([0, 0, 0]) #this value for the RGB image if you want to mask in grayscale then you have to pass only one value.
hv = np.array([220, 220, 220])
mask = cv2.inRange(image2, lv, hv)
plt.imshow(mask, cmap = 'gray')
plt.show()

# %%
masked_img = image2.copy()
masked_img[mask!=255] = [0, 0, 0]
plt.imshow(masked_img)
plt.show()

# %%
masked_img.shape
# Out:
# (1000, 1000, 3)

# %%
sky_bg.shape
# Out:
# (683, 1024, 3)

# %%
resize = cv2.resize(sky_bg, (1000, 1000))

# %%
masked_img.shape, resize.shape
# Out:
# ((1000, 1000, 3), (1000, 1000, 3))

# %%
bg_cpy = resize.copy()
bg_cpy[mask == [255]] = [0, 0, 0]
plt.imshow(bg_cpy)
plt.show()

# %%
bg_cpy.shape, resize.shape
# Out:
# ((1000, 1000, 3), (1000, 1000, 3))

# %%
final = masked_img + resize
plt.imshow(final)
plt.show()

# %%
cv2.__version__
# Out:
# '4.1.0'
